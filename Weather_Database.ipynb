# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print(len(coordinates))
# Out:
# 2000

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
countries = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country =  citipy.nearest_city(coordinate[0], coordinate[1]).country_code

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        countries.append(country)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except KeyError as e:
        print("City not found. Skipping...")
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | burns lake
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | shibetsu
# Processing Record 6 of Set 1 | sawtell
# Processing Record 7 of Set 1 | rawson
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | santa cruz
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | port hedland
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | salalah
# Processing Record 17 of Set 1 | callaguip
# Processing Record 18 of Set 1 | nioro
# Processing Record 19 of Set 1 | inongo
# Processing Record 20 of Set 1 | micomeseng
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | puerto leguizamo
# Processing Record 25 of Set 1 | pastavy
# Processing Record 26 of Set 1 | ibra
# Processing Record 27 of Set 1 | namie
# Processing Record 28 of Set 1 | dehloran
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | great falls
# Processing Record 32 of Set 1 | zaozerne
# Processing Record 33 of Set 1 | nicolas bravo
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 1 | tashla
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | miles city
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | agadez
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | sovetskiy
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | srednekolymsk
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | nivala
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | beloha
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | ginir
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | awbari
# Processing Record 11 of Set 2 | san carlos
# Processing Record 12 of Set 2 | timaru
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | kamina
# Processing Record 15 of Set 2 | blankenberge
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | karauli
# Processing Record 19 of Set 2 | ahuimanu
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | prince rupert
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | kikwit
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 2 | laguna
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | dolbeau
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | zyryanka
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 2 | bilibino
# Processing Record 33 of Set 2 | aswan
# Processing Record 34 of Set 2 | avera
# Processing Record 35 of Set 2 | svodin
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | prudy
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 2 | ahipara
# Processing Record 41 of Set 2 | mpigi
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | nagaur
# Processing Record 44 of Set 2 | broome
# Processing Record 45 of Set 2 | rikitea
# Processing Record 46 of Set 2 | nhulunbuy
# Processing Record 47 of Set 2 | moose factory
# Processing Record 48 of Set 2 | faya
# Processing Record 49 of Set 2 | seregelyes
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | berat
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 3 | aklavik
# Processing Record 4 of Set 3 | peleduy
# Processing Record 5 of Set 3 | belmonte
# Processing Record 6 of Set 3 | fukue
# Processing Record 7 of Set 3 | tessalit
# Processing Record 8 of Set 3 | grand centre
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 3 | bahia blanca
# Processing Record 10 of Set 3 | mahibadhoo
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 3 | dabat
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | eyrarbakki
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | carbondale
# Processing Record 17 of Set 3 | najran
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | kutum
# Processing Record 20 of Set 3 | anaconda
# Processing Record 21 of Set 3 | wahran
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 3 | dunedin
# Processing Record 23 of Set 3 | logan lake
# Processing Record 24 of Set 3 | shubarshi
# Processing Record 25 of Set 3 | ponta delgada
# Processing Record 26 of Set 3 | urubicha
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | mocambique
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | hervey bay
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | dolinsk
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | nouadhibou
# Processing Record 37 of Set 3 | dwarahat
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | esso
# Processing Record 40 of Set 3 | cabedelo
# Processing Record 41 of Set 3 | tigil
# Processing Record 42 of Set 3 | padang
# Processing Record 43 of Set 3 | shache
# Processing Record 44 of Set 3 | fevralsk
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 3 | linqiong
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | ngukurr
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 3 | mpanda
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | hanko
# Processing Record 2 of Set 4 | burnie
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | ust-kuyga
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | mahajanga
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | teknaf
# Processing Record 10 of Set 4 | taburao
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 4 | zhanaozen
# Processing Record 12 of Set 4 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 4 | camacha
# Processing Record 14 of Set 4 | chapleau
# Processing Record 15 of Set 4 | preston
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | san nicolas guadalupe
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | tommot
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 4 | volchikha
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | yulara
# Processing Record 28 of Set 4 | udachnyy
# Processing Record 29 of Set 4 | fort nelson
# Processing Record 30 of Set 4 | port-gentil
# Processing Record 31 of Set 4 | el vigia
# Processing Record 32 of Set 4 | atuona
# Processing Record 33 of Set 4 | batsfjord
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 4 | moindou
# Processing Record 36 of Set 4 | rungata
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | karkaralinsk
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 4 | yarada
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | suntar
# Processing Record 42 of Set 4 | tadine
# Processing Record 43 of Set 4 | rio gallegos
# Processing Record 44 of Set 4 | peniche
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 4 | thul
# Processing Record 47 of Set 4 | georgetown
# Processing Record 48 of Set 4 | zhigansk
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | mount hagen
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | leua
# Processing Record 3 of Set 5 | airai
# Processing Record 4 of Set 5 | baran
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | piacabucu
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | cedar city
# Processing Record 9 of Set 5 | grindavik
# Processing Record 10 of Set 5 | manta
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | new norfolk
# Processing Record 14 of Set 5 | manggar
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | byron bay
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | hofn
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | rovaniemi
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | kaduna
# Processing Record 24 of Set 5 | waipawa
# Processing Record 25 of Set 5 | ayan
# Processing Record 26 of Set 5 | harindanga
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 5 | nelidovo
# Processing Record 29 of Set 5 | kruisfontein
# Processing Record 30 of Set 5 | sao joao da barra
# Processing Record 31 of Set 5 | longyearbyen
# Processing Record 32 of Set 5 | ardusat
# Processing Record 33 of Set 5 | los llanos de aridane
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | riyadh
# Processing Record 37 of Set 5 | pochutla
# Processing Record 38 of Set 5 | tocache
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | khislavichi
# Processing Record 41 of Set 5 | mabaruma
# Processing Record 42 of Set 5 | zheleznodorozhnyy
# Processing Record 43 of Set 5 | coihaique
# Processing Record 44 of Set 5 | apomu
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | verkhnyaya inta
# Processing Record 47 of Set 5 | xuddur
# Processing Record 48 of Set 5 | kongolo
# Processing Record 49 of Set 5 | corrales
# Processing Record 50 of Set 5 | progreso
# Processing Record 1 of Set 6 | tongchuan
# Processing Record 2 of Set 6 | comodoro rivadavia
# Processing Record 3 of Set 6 | ushibuka
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | okha
# Processing Record 6 of Set 6 | haines junction
# Processing Record 7 of Set 6 | gojra
# Processing Record 8 of Set 6 | gat
# Processing Record 9 of Set 6 | cockburn town
# Processing Record 10 of Set 6 | alofi
# Processing Record 11 of Set 6 | eskasem
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | shenzhen
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | socorro
# Processing Record 16 of Set 6 | vila
# Processing Record 17 of Set 6 | fergus falls
# Processing Record 18 of Set 6 | vila do maio
# Processing Record 19 of Set 6 | joshimath
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | goderich
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | utiroa
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 6 | skiros
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 6 | kangaatsiaq
# Processing Record 26 of Set 6 | ito
# Processing Record 27 of Set 6 | acajutla
# Processing Record 28 of Set 6 | kargala
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | tuy hoa
# Processing Record 31 of Set 6 | saint pete beach
# Processing Record 32 of Set 6 | mindelo
# Processing Record 33 of Set 6 | tiksi
# Processing Record 34 of Set 6 | vardo
# Processing Record 35 of Set 6 | acapulco
# Processing Record 36 of Set 6 | ust-nera
# Processing Record 37 of Set 6 | port shepstone
# Processing Record 38 of Set 6 | rajula
# Processing Record 39 of Set 6 | huarmey
# Processing Record 40 of Set 6 | kosh-agach
# Processing Record 41 of Set 6 | hualmay
# Processing Record 42 of Set 6 | karratha
# Processing Record 43 of Set 6 | ngudu
# Processing Record 44 of Set 6 | zhenhai
# Processing Record 45 of Set 6 | mackenzie
# Processing Record 46 of Set 6 | priladozhskiy
# Processing Record 47 of Set 6 | esperance
# Processing Record 48 of Set 6 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 6 | normandin
# Processing Record 50 of Set 6 | ostrovnoy
# Processing Record 1 of Set 7 | samana
# Processing Record 2 of Set 7 | dentsville
# Processing Record 3 of Set 7 | trat
# Processing Record 4 of Set 7 | dera bugti
# Processing Record 5 of Set 7 | tshikapa
# Processing Record 6 of Set 7 | torbay
# Processing Record 7 of Set 7 | south milwaukee
# Processing Record 8 of Set 7 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 7 | narok
# Processing Record 10 of Set 7 | bhawana
# Processing Record 11 of Set 7 | port hardy
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | marsaxlokk
# Processing Record 14 of Set 7 | bethel
# Processing Record 15 of Set 7 | itanhandu
# Processing Record 16 of Set 7 | haimen
# Processing Record 17 of Set 7 | dhidhdhoo
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | reconquista
# Processing Record 20 of Set 7 | barmer
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | lata
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 7 | yantal
# Processing Record 25 of Set 7 | shimoda
# Processing Record 26 of Set 7 | muros
# Processing Record 27 of Set 7 | porbandar
# Processing Record 28 of Set 7 | port elizabeth
# Processing Record 29 of Set 7 | chimbote
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | caernarfon
# Processing Record 32 of Set 7 | sistranda
# Processing Record 33 of Set 7 | tautira
# Processing Record 34 of Set 7 | kamenka
# Processing Record 35 of Set 7 | christchurch
# Processing Record 36 of Set 7 | arlit
# Processing Record 37 of Set 7 | keffi
# Processing Record 38 of Set 7 | kensington
# Processing Record 39 of Set 7 | desaguadero
# Processing Record 40 of Set 7 | honningsvag
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 7 | casma
# Processing Record 43 of Set 7 | basoko
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | kaitangata
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | bundaberg
# Processing Record 48 of Set 7 | roald
# Processing Record 49 of Set 7 | zhetybay
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 7 | tondano
# Processing Record 1 of Set 8 | brive-la-gaillarde
# Processing Record 2 of Set 8 | bow island
# Processing Record 3 of Set 8 | lowestoft
# Processing Record 4 of Set 8 | uvat
# Processing Record 5 of Set 8 | maiduguri
# Processing Record 6 of Set 8 | visnes
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | morros
# Processing Record 9 of Set 8 | daru
# Processing Record 10 of Set 8 | contai
# Processing Record 11 of Set 8 | cabo san lucas
# Processing Record 12 of Set 8 | lagos
# Processing Record 13 of Set 8 | oregon city
# Processing Record 14 of Set 8 | natal
# Processing Record 15 of Set 8 | smoky lake
# Processing Record 16 of Set 8 | villa de reyes
# Processing Record 17 of Set 8 | lorengau
# Processing Record 18 of Set 8 | nemuro
# Processing Record 19 of Set 8 | hovd
# Processing Record 20 of Set 8 | babushkin
# Processing Record 21 of Set 8 | yenagoa
# Processing Record 22 of Set 8 | batagay
# Processing Record 23 of Set 8 | nguiu
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 8 | sisimiut
# Processing Record 25 of Set 8 | maniitsoq
# Processing Record 26 of Set 8 | florence
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | champerico
# Processing Record 29 of Set 8 | patitirion
# Processing Record 30 of Set 8 | saint-augustin
# Processing Record 31 of Set 8 | port lincoln
# Processing Record 32 of Set 8 | ganzhou
# Processing Record 33 of Set 8 | aden
# Processing Record 34 of Set 8 | faanui
# Processing Record 35 of Set 8 | la primavera
# Processing Record 36 of Set 8 | rawannawi
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | yerbogachen
# Processing Record 39 of Set 8 | swan river
# Processing Record 40 of Set 8 | tabat
# Processing Record 41 of Set 8 | safaga
# Processing Record 42 of Set 8 | sabang
# Processing Record 43 of Set 8 | itarema
# Processing Record 44 of Set 8 | omsukchan
# Processing Record 45 of Set 8 | mehamn
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | sakakah
# Processing Record 48 of Set 8 | biscarrosse
# Processing Record 49 of Set 8 | formoso do araguaia
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 8 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 9 | terrace bay
# Processing Record 2 of Set 9 | stadskanaal
# Processing Record 3 of Set 9 | buta
# Processing Record 4 of Set 9 | impfondo
# Processing Record 5 of Set 9 | antofagasta
# Processing Record 6 of Set 9 | oga
# Processing Record 7 of Set 9 | tairua
# Processing Record 8 of Set 9 | dikson
# Processing Record 9 of Set 9 | sagua la grande
# Processing Record 10 of Set 9 | tres lagoas
# Processing Record 11 of Set 9 | sorong
# Processing Record 12 of Set 9 | ust-kulom
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | meyungs
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 9 | synya
# Processing Record 16 of Set 9 | khartoum
# Processing Record 17 of Set 9 | kokopo
# Processing Record 18 of Set 9 | mezen
# Processing Record 19 of Set 9 | walvis bay
# Processing Record 20 of Set 9 | college
# Processing Record 21 of Set 9 | vestmannaeyjar
# Processing Record 22 of Set 9 | ijaki
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 9 | svetlogorsk
# Processing Record 24 of Set 9 | zinder
# Processing Record 25 of Set 9 | bose
# Processing Record 26 of Set 9 | manicore
# Processing Record 27 of Set 9 | kushmurun
# Processing Record 28 of Set 9 | taltal
# Processing Record 29 of Set 9 | tonstad
# Processing Record 30 of Set 9 | luwuk
# Processing Record 31 of Set 9 | khonuu
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 9 | juneau
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | kota bahru
# Processing Record 35 of Set 9 | kokstad
# Processing Record 36 of Set 9 | itaporanga
# Processing Record 37 of Set 9 | eching
# Processing Record 38 of Set 9 | pak phanang
# Processing Record 39 of Set 9 | sungairaya
# Processing Record 40 of Set 9 | kasganj
# Processing Record 41 of Set 9 | caceres
# Processing Record 42 of Set 9 | tonantins
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | camara de lobos
# Processing Record 45 of Set 9 | kiunga
# Processing Record 46 of Set 9 | huayapam
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 9 | ladario
# Processing Record 48 of Set 9 | constitucion
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | cayenne
# Processing Record 1 of Set 10 | san quintin
# Processing Record 2 of Set 10 | nanortalik
# Processing Record 3 of Set 10 | addi ugri
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 10 | nitra
# Processing Record 5 of Set 10 | tignere
# Processing Record 6 of Set 10 | poum
# Processing Record 7 of Set 10 | chandur bazar
# Processing Record 8 of Set 10 | kamenskoye
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 10 | dingle
# Processing Record 10 of Set 10 | kara
# Processing Record 11 of Set 10 | gondar
# Processing Record 12 of Set 10 | mirabad
# Processing Record 13 of Set 10 | ilulissat
# Processing Record 14 of Set 10 | lingao
# Processing Record 15 of Set 10 | saravan
# Processing Record 16 of Set 10 | batagay-alyta
# Processing Record 17 of Set 10 | taksimo
# Processing Record 18 of Set 10 | praya
# Processing Record 19 of Set 10 | deputatskiy
# Processing Record 20 of Set 10 | marigot
# Processing Record 21 of Set 10 | sosnovo-ozerskoye
# Processing Record 22 of Set 10 | ostersund
# Processing Record 23 of Set 10 | sarti
# Processing Record 24 of Set 10 | negombo
# Processing Record 25 of Set 10 | inderborskiy
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 10 | llanes
# Processing Record 27 of Set 10 | san matias
# Processing Record 28 of Set 10 | benton harbor
# Processing Record 29 of Set 10 | matara
# Processing Record 30 of Set 10 | luau
# Processing Record 31 of Set 10 | pochinki
# Processing Record 32 of Set 10 | winslow
# Processing Record 33 of Set 10 | wamba
# Processing Record 34 of Set 10 | sayyan
# Processing Record 35 of Set 10 | zaozhuang
# Processing Record 36 of Set 10 | port moresby
# Processing Record 37 of Set 10 | alto longa
# Processing Record 38 of Set 10 | boa vista
# Processing Record 39 of Set 10 | ciudad bolivar
# Processing Record 40 of Set 10 | bayir
# Processing Record 41 of Set 10 | yeletskiy
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 10 | cape canaveral
# Processing Record 43 of Set 10 | chegdomyn
# Processing Record 44 of Set 10 | souillac
# Processing Record 45 of Set 10 | solnechnyy
# Processing Record 46 of Set 10 | trairi
# Processing Record 47 of Set 10 | kiama
# Processing Record 48 of Set 10 | viligili
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | santa maria
# Processing Record 1 of Set 11 | hobyo
# Processing Record 2 of Set 11 | sao gabriel da cachoeira
# Processing Record 3 of Set 11 | raton
# Processing Record 4 of Set 11 | menzelinsk
# Processing Record 5 of Set 11 | merauke
# Processing Record 6 of Set 11 | crotone
# Processing Record 7 of Set 11 | ouesso
# Processing Record 8 of Set 11 | charters towers
# Processing Record 9 of Set 11 | celestun
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | belaya gora
# Processing Record 12 of Set 11 | los alamos
# Processing Record 13 of Set 11 | egvekinot
# Processing Record 14 of Set 11 | port blair
# Processing Record 15 of Set 11 | solginskiy
# Processing Record 16 of Set 11 | chagda
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 11 | guerrero negro
# Processing Record 18 of Set 11 | isangel
# Processing Record 19 of Set 11 | husavik
# Processing Record 20 of Set 11 | igarka
# Processing Record 21 of Set 11 | coquimbo
# Processing Record 22 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 11 | missoula
# Processing Record 24 of Set 11 | kidal
# Processing Record 25 of Set 11 | san policarpo
# Processing Record 26 of Set 11 | yanan
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 11 | saint-francois
# Processing Record 28 of Set 11 | isabela
# Processing Record 29 of Set 11 | changji
# Processing Record 30 of Set 11 | cairns
# Processing Record 31 of Set 11 | nome
# Processing Record 32 of Set 11 | beachwood
# Processing Record 33 of Set 11 | sao jose da coroa grande
# Processing Record 34 of Set 11 | vestmanna
# Processing Record 35 of Set 11 | samalaeulu
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 11 | polazna
# Processing Record 37 of Set 11 | hunza
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | oktyabrskoye
# Processing Record 40 of Set 11 | burica
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 11 | dauriya
# Processing Record 42 of Set 11 | vanimo
# Processing Record 43 of Set 11 | thinadhoo
# Processing Record 44 of Set 11 | tumut
# Processing Record 45 of Set 11 | bloemfontein
# Processing Record 46 of Set 11 | abu kamal
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | birjand
# Processing Record 49 of Set 11 | linxi
# Processing Record 50 of Set 11 | kurilsk
# Processing Record 1 of Set 12 | harer
# Processing Record 2 of Set 12 | cuxhaven
# Processing Record 3 of Set 12 | dolzhanskaya
# Processing Record 4 of Set 12 | okato
# Processing Record 5 of Set 12 | sumbawa
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 12 | altus
# Processing Record 7 of Set 12 | pemangkat
# Processing Record 8 of Set 12 | mischii
# Processing Record 9 of Set 12 | khromtau
# Processing Record 10 of Set 12 | coahuayana
# Processing Record 11 of Set 12 | tupelo
# Processing Record 12 of Set 12 | isiro
# Processing Record 13 of Set 12 | sarangpur
# Processing Record 14 of Set 12 | vao
# Processing Record 15 of Set 12 | west wendover
# Processing Record 16 of Set 12 | tiarei
# Processing Record 17 of Set 12 | bolungarvik
# City not found. Skipping...
# 'coord'
# Processing Record 18 of Set 12 | aleksandrov gay
# Processing Record 19 of Set 12 | abu jubayhah
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 12 | asau
# Processing Record 21 of Set 12 | kempele
# Processing Record 22 of Set 12 | seoul
# Processing Record 23 of Set 12 | grand bank
# Processing Record 24 of Set 12 | teguise
# Processing Record 25 of Set 12 | antalaha
# Processing Record 26 of Set 12 | bur gabo
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | jalu
# Processing Record 29 of Set 12 | sernur
# Processing Record 30 of Set 12 | tornio
# Processing Record 31 of Set 12 | graaff-reinet
# Processing Record 32 of Set 12 | urubamba
# Processing Record 33 of Set 12 | sorvag
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 12 | odienne
# Processing Record 35 of Set 12 | wahiawa
# Processing Record 36 of Set 12 | flin flon
# Processing Record 37 of Set 12 | mengcheng
# Processing Record 38 of Set 12 | viadana
# Processing Record 39 of Set 12 | serafimovskiy
# Processing Record 40 of Set 12 | villach
# Processing Record 41 of Set 12 | sedan
# Processing Record 42 of Set 12 | puerto maldonado
# Processing Record 43 of Set 12 | sompeta
# Processing Record 44 of Set 12 | turangi
# Processing Record 45 of Set 12 | half moon bay
# Processing Record 46 of Set 12 | mutoko
# Processing Record 47 of Set 12 | kegayli
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 12 | balykshi
# Processing Record 49 of Set 12 | sukhobezvodnoye
# Processing Record 50 of Set 12 | zalesovo
# Processing Record 1 of Set 13 | kirakira
# Processing Record 2 of Set 13 | maymyo
# Processing Record 3 of Set 13 | angra
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 13 | abu samrah
# Processing Record 5 of Set 13 | taunggyi
# Processing Record 6 of Set 13 | pelym
# Processing Record 7 of Set 13 | varnamo
# Processing Record 8 of Set 13 | talara
# Processing Record 9 of Set 13 | huazhou
# Processing Record 10 of Set 13 | barranca
# Processing Record 11 of Set 13 | naryan-mar
# Processing Record 12 of Set 13 | guatire
# Processing Record 13 of Set 13 | shumskiy
# Processing Record 14 of Set 13 | havoysund
# Processing Record 15 of Set 13 | alekseyevsk
# Processing Record 16 of Set 13 | tynset
# Processing Record 17 of Set 13 | dongsheng
# Processing Record 18 of Set 13 | turayf
# Processing Record 19 of Set 13 | agarak
# Processing Record 20 of Set 13 | waingapu
# Processing Record 21 of Set 13 | hajnowka
# Processing Record 22 of Set 13 | ballina
# Processing Record 23 of Set 13 | leningradskiy
# Processing Record 24 of Set 13 | inhambane
# Processing Record 25 of Set 13 | qianguo
# Processing Record 26 of Set 13 | astipalaia
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 13 | mudgee
# Processing Record 28 of Set 13 | gympie
# Processing Record 29 of Set 13 | necochea
# Processing Record 30 of Set 13 | akyab
# Processing Record 31 of Set 13 | sobolevo
# Processing Record 32 of Set 13 | homer
# Processing Record 33 of Set 13 | galle
# Processing Record 34 of Set 13 | dzhusaly
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 13 | vila franca do campo
# Processing Record 36 of Set 13 | buon me thuot
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 13 | kazalinsk
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 13 | henties bay
# Processing Record 39 of Set 13 | mersing
# Processing Record 40 of Set 13 | ambajogai
# Processing Record 41 of Set 13 | aitape
# Processing Record 42 of Set 13 | sodertalje
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 13 | ust-maya
# Processing Record 44 of Set 13 | bagdarin
# Processing Record 45 of Set 13 | taveta
# Processing Record 46 of Set 13 | baiquan
# Processing Record 47 of Set 13 | oistins
# Processing Record 48 of Set 13 | kearney
# Processing Record 49 of Set 13 | dwarka
# Processing Record 50 of Set 13 | newport
# Processing Record 1 of Set 14 | virginia beach
# Processing Record 2 of Set 14 | sungaipenuh
# Processing Record 3 of Set 14 | adrar
# Processing Record 4 of Set 14 | sur
# Processing Record 5 of Set 14 | coruripe
# Processing Record 6 of Set 14 | bairiki
# Processing Record 7 of Set 14 | bhairab bazar
# Processing Record 8 of Set 14 | yuli
# Processing Record 9 of Set 14 | houston
# Processing Record 10 of Set 14 | slave lake
# Processing Record 11 of Set 14 | ouadda
# Processing Record 12 of Set 14 | bartica
# Processing Record 13 of Set 14 | namtsy
# Processing Record 14 of Set 14 | sola
# Processing Record 15 of Set 14 | santa isabel
# Processing Record 16 of Set 14 | iwanai
# Processing Record 17 of Set 14 | jinhua
# Processing Record 18 of Set 14 | urumqi
# Processing Record 19 of Set 14 | priego de cordoba
# Processing Record 20 of Set 14 | atakpame
# Processing Record 21 of Set 14 | chabahar
# Processing Record 22 of Set 14 | magadan
# Processing Record 23 of Set 14 | san rafael
# Processing Record 24 of Set 14 | maningrida
# Processing Record 25 of Set 14 | kinkala
# Processing Record 26 of Set 14 | nha trang
# Processing Record 27 of Set 14 | esil
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | caboolture
# Processing Record 30 of Set 14 | mayo
# Processing Record 31 of Set 14 | coolum beach
# Processing Record 32 of Set 14 | marsh harbour
# Processing Record 33 of Set 14 | artyk
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 14 | saint-pierre
# Processing Record 35 of Set 14 | fort-shevchenko
# Processing Record 36 of Set 14 | aksu
# Processing Record 37 of Set 14 | tecalitlan
# Processing Record 38 of Set 14 | kazachinskoye
# Processing Record 39 of Set 14 | margate
# Processing Record 40 of Set 14 | freeport
# Processing Record 41 of Set 14 | zabaykalsk
# Processing Record 42 of Set 14 | nueva loja
# Processing Record 43 of Set 14 | innisfail
# Processing Record 44 of Set 14 | mamakan
# Processing Record 45 of Set 14 | whitehorse
# Processing Record 46 of Set 14 | upata
# Processing Record 47 of Set 14 | nelson bay
# Processing Record 48 of Set 14 | tucumcari
# Processing Record 49 of Set 14 | bayan
# Processing Record 50 of Set 14 | tezu
# Processing Record 1 of Set 15 | taldom
# Processing Record 2 of Set 15 | kununurra
# Processing Record 3 of Set 15 | raudeberg
# Processing Record 4 of Set 15 | acarau
# Processing Record 5 of Set 15 | tabuk
# Processing Record 6 of Set 15 | rancagua
# Processing Record 7 of Set 15 | aykhal
# Processing Record 8 of Set 15 | te anau
# Processing Record 9 of Set 15 | sibu
# Processing Record 10 of Set 15 | alta floresta
# Processing Record 11 of Set 15 | nanga eboko
# Processing Record 12 of Set 15 | tripoli
# Processing Record 13 of Set 15 | sibolga
# Processing Record 14 of Set 15 | marawi
# Processing Record 15 of Set 15 | mitsamiouli
# Processing Record 16 of Set 15 | chumikan
# Processing Record 17 of Set 15 | port hueneme
# Processing Record 18 of Set 15 | weyburn
# Processing Record 19 of Set 15 | kalmunai
# Processing Record 20 of Set 15 | tazmalt
# Processing Record 21 of Set 15 | bon air
# Processing Record 22 of Set 15 | raboso
# Processing Record 23 of Set 15 | tomatlan
# Processing Record 24 of Set 15 | ambilobe
# Processing Record 25 of Set 15 | swan hill
# Processing Record 26 of Set 15 | pacific grove
# Processing Record 27 of Set 15 | bandar-e lengeh
# Processing Record 28 of Set 15 | guangyuan
# Processing Record 29 of Set 15 | san andres
# Processing Record 30 of Set 15 | vilhena
# Processing Record 31 of Set 15 | teya
# Processing Record 32 of Set 15 | la paz
# Processing Record 33 of Set 15 | glace bay
# Processing Record 34 of Set 15 | puerto ayacucho
# Processing Record 35 of Set 15 | morehead
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
print(len(city_data)) 

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# 671
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     54.48        71         100
# 1       Hobart      AU -42.8794  147.3294     48.25        96          75
# 2   Burns Lake      CA  54.2331 -125.7533     49.42        58         100
# 3     Khatanga      RU  71.9667  102.5000     34.29        81          85
# 4     Shibetsu      JP  43.6590  145.1320     54.30        66          75
# 5      Sawtell      AU -30.3833  153.1000     64.42        59           2
# 6       Rawson      AR -43.3002  -65.1023     41.79        57          63
# 7  Tuktoyaktuk      CA  69.4541 -133.0374     32.00        86          75
# 8       Kodiak      US  57.7900 -152.4072     65.71        42           0
# 9    Busselton      AU -33.6500  115.3333     58.19        56          98
#
#    Wind Speed Current Discription
# 0        2.89     overcast clouds
# 1       12.66                 fog
# 2        8.46     overcast clouds
# 3       14.18     overcast clouds
# 4       11.50       broken clouds
# 5       10.36           clear sky
# 6       20.65       broken clouds
# 7       10.36       broken clouds
# 8        5.75           clear sky
# 9       16.67     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/Weatherpy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
